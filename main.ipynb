# %%
#Vikas, please use this code for data generation
#Multivariate data generator. Positives and negatives are both gaussian mixtures of the same 
#number of components. A positive components is uniquely paired with a negative component. 
# First the paired compnents are learnt to satisfy the AUCPN and irreducibility constraints. 
# Once the pairs satisfy the constraints, the relative position of the + and - component within
# a pair is fixed. 
# Then each pair is moved around in the sapce so that the irreducibility and AUCPN constraint is 
# satisfied. Note that the upper limit of the AUC constraint may not be satisfied between
# the components from different pairs. But the lower limit should be satisfied between them,
# even between the positive (or negative) components from different pairs.
# Note that the final AUCPN between all positives and negatives might be outsided the AUCPN
# range. The final AUCPN will also depend on alpha and the proportion in which the components 
# within the positive mixture (and negative mixture) are mixed. 
from data.randomParameters import NormalMixPNParameters2 as NMixPar
from scipy.stats import dirichlet
from data.utils import AUCFromDistributions
def GaussianMixtureDataGenerator(dim, n_comps, aucpn_range, irr_vec):
    NMix = NMixPar(dim, n_comps)
    NMix.perturb2SatisfyMetrics(aucpn_range, irr_vec)
    dg = NMix.dg
    return NMix, dg

#Dimension
dim = 2
#Number of components in positves and negatives each
n_comps = 4
# Setting the thrid entry of irr_vec to False enforces pairwise (between pair of any two compnents)
# mutual irreducibility
# setting the thrid entry of irr_vec to True enforces the strong irreducibility, where each 
# component is irreducible w.r.t. all other components considered together.
# The second entry of irr_vec is the the balanced posterior (responsibility) threshold for irreducibility.
# The first argument is the proportion of points that ought to satisfy the posterior threshold
# for irreducibility to hold true. Using 0.01 and 0.9 is easier to satisfy then 0.05 and 0.95. 
# You may play with this, but note that the stronger irreducibility criteria, the more difficult 
# it is to be satisfied and you might end up in infinite loop since no parameters could be 
# found to satisfy both the irreducibility and auc criteria.
irr_vec = [0.01, 0.9, True]
# aucpn_range contains the desired range of AUCPN to be satisfied between the paired positive 
# and negative component.
# Once the constraints are satisfied between the paired components. The paired components are
# moved together further or close to the other paired components that the AUC constraints can be satisfied between unpaired components
# to the extent possible.
#The minimum AUC range for 1 dimensional datasets is [0.7, 0.75].
#If the AUC range is smaller than that irreducibility can't be achieved when using 
#irr_vec = [0.01, 0.9, False]
aucpn_range = [0.7, 0.75]
#Dataset size
n = 20000
#proportion of positives
alpha = 0.5
NMix, dg = GaussianMixtureDataGenerator(dim, n_comps, aucpn_range, irr_vec)
#x contains the features and y contains the class labels
x, y = dg.pn_data(n)[0:2]
aucpn_final = AUCFromDistributions(dg.dist_p, dg.dist_n)
print(aucpn_final)
# Out:
# isMetricSatisfied{'aucpn': 0.5, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.64363868, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6509758, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.63358392, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.69870548, 'irreducibility': [0.0074, 0.0062]}
# anchorSetProp0.01
# Sigma Scale Perturb
# 0.75
# Sigma Ratios: [1.     0.5625]
# Sigma Ratios: [1.     0.5625]
# isMetricSatisfied{'aucpn': 0.73019352, 'irreducibility': [0.0, 0.0684]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.74411348, 'irreducibility': [0.0, 0.0826]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.74011728, 'irreducibility': [0.0, 0.0788]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.73436476, 'irreducibility': [0.0, 0.0876]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.74260264, 'irreducibility': [0.0, 0.0898]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.73297612, 'irreducibility': [0.0, 0.081]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.7382080400000001, 'irreducibility': [0.0, 0.0784]}
# anchorSetProp0.01
# Sigma Scale Perturb
# 0.75
# 0.875
# Sigma Ratios: [1.         0.43066406]
# 0.9375
# Sigma Ratios: [1.         0.49438477]
# 0.96875
# Sigma Ratios: [1.         0.52789307]
# Sigma Ratios: [1.         0.52789307]
# isMetricSatisfied{'aucpn': 0.7400406000000002, 'irreducibility': [0.0, 0.096]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.7388545200000001, 'irreducibility': [0.0, 0.0924]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.74625736, 'irreducibility': [0.0, 0.102]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.74476336, 'irreducibility': [0.0, 0.0948]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.7512744, 'irreducibility': [0.0, 0.1018]}
# anchorSetProp0.01
# Sigma Scale Perturb
# 0.75
# 0.875
# 0.9375
# 0.96875
# Sigma Ratios: [1.77777778 1.        ]
# Sigma Ratios: [1.77777778 1.        ]
# isMetricSatisfied{'aucpn': 0.75346672, 'irreducibility': [0.0, 0.1048]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [1.86373026 1.        ]
# Sigma Ratios: [1.86373026 1.        ]
# isMetricSatisfied{'aucpn': 0.7558050799999999, 'irreducibility': [0.0, 0.1046]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.75152332, 'irreducibility': [0.0, 0.1014]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.58435448, 'irreducibility': [0.0, 0.0022]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.5848943200000001, 'irreducibility': [0.0, 0.0028]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6905443600000001, 'irreducibility': [0.0, 0.0408]}
# anchorSetProp0.01
# Sigma Scale Perturb
# 0.75
# Sigma Ratios: [1.         0.30181406]
# 0.875
# Sigma Ratios: [1.         0.41080247]
# 0.9375
# Sigma Ratios: [1.         0.47158447]
# 0.96875
# Sigma Ratios: [1.         0.50354742]
# Sigma Ratios: [1.         0.50354742]
# isMetricSatisfied{'aucpn': 0.70391916, 'irreducibility': [0.0, 0.0532]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.69791864, 'irreducibility': [0.0, 0.0556]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [2.97454398 1.        ]
# Sigma Ratios: [2.77627301 1.        ]
# Sigma Ratios: [2.45510312 1.        ]
# Sigma Ratios: [2.23900957 1.        ]
# Sigma Ratios: [2.11708565 1.        ]
# Sigma Ratios: [2.0526544 1.       ]
# Sigma Ratios: [2.01957145 1.        ]
# Sigma Ratios: [2.00281314 1.        ]
# Sigma Ratios: [1.99437979 1.        ]
# Sigma Ratios: [1.99437979 1.        ]
# isMetricSatisfied{'aucpn': 0.6924434399999999, 'irreducibility': [0.0, 0.0482]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.6993296400000001, 'irreducibility': [0.0, 0.0546]}
# anchorSetProp0.01
# Sigma Scale Perturb
# Sigma Ratios: [0.49859495 1.        ]
# 0.75
# Sigma Ratios: [1.12183863 1.        ]
# Sigma Ratios: [1.12183863 1.        ]
# isMetricSatisfied{'aucpn': 0.70393964, 'irreducibility': [0.0042, 0.0102]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [1.69674098 1.        ]
# Sigma Ratios: [1.69674098 1.        ]
# isMetricSatisfied{'aucpn': 0.71926472, 'irreducibility': [0.015, 0.0378]}
# anchorSetProp0.01
# isMetricSatisfied{'aucpn': 0.5, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6402070799999999, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [1.         0.93715335]
# Sigma Ratios: [1.         0.93715335]
# isMetricSatisfied{'aucpn': 0.67879428, 'irreducibility': [0.0238, 0.035]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.67800916, 'irreducibility': [0.024, 0.0328]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6941436000000001, 'irreducibility': [0.0532, 0.015]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.6894309200000001, 'irreducibility': [0.0502, 0.0166]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.68624292, 'irreducibility': [0.0552, 0.0144]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.6825845199999999, 'irreducibility': [0.0502, 0.0126]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [0.949334 1.      ]
# Sigma Ratios: [0.949334 1.      ]
# isMetricSatisfied{'aucpn': 0.7278896399999999, 'irreducibility': [0.108, 0.0514]}
# anchorSetProp0.01
# isMetricSatisfied{'aucpn': 0.5, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6367758, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.7316492399999999, 'irreducibility': [0.0228, 0.0174]}
# anchorSetProp0.01
# isMetricSatisfied{'aucpn': 0.5, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Sigma Scale Perturb
# Sigma Ratios: [1.   0.25]
# 0.75
# Sigma Ratios: [1.     0.5625]
# Sigma Ratios: [1.     0.5625]
# isMetricSatisfied{'aucpn': 0.57096076, 'irreducibility': [0.0, 0.0002]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.5634547599999999, 'irreducibility': [0.0, 0.0]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [4.00357501 1.        ]
# Sigma Ratios: [3.05278814 1.        ]
# Sigma Ratios: [2.4558109 1.       ]
# Sigma Ratios: [2.12692632 1.        ]
# Sigma Ratios: [1.95488505 1.        ]
# Sigma Ratios: [1.95488505 1.        ]
# isMetricSatisfied{'aucpn': 0.5795743200000001, 'irreducibility': [0.0, 0.002]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6592263599999999, 'irreducibility': [0.0, 0.0286]}
# anchorSetProp0.01
# Sigma Scale Perturb
# Sigma Ratios: [0.48872126 1.        ]
# 0.75
# Sigma Ratios: [1.09962284 1.        ]
# Sigma Ratios: [1.09962284 1.        ]
# isMetricSatisfied{'aucpn': 0.66040916, 'irreducibility': [0.0, 0.0044]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.70502448, 'irreducibility': [0.0014, 0.022]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.7174746799999999, 'irreducibility': [0.0012, 0.023]}
# anchorSetProp0.01
# Sigma Scale Perturb
# 0.75
# Sigma Ratios: [0.61853785 1.        ]
# Sigma Ratios: [0.61853785 1.        ]
# isMetricSatisfied{'aucpn': 0.7390497599999999, 'irreducibility': [0.0634, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.6035112, 'irreducibility': [0.0032, 0.0]}
# anchorSetProp0.01
# Mu Perturb
# isMetricSatisfied{'aucpn': 0.75644808, 'irreducibility': [0.095, 0.0004]}
# anchorSetProp0.01
# Perturb Proportion
# isMetricSatisfied{'aucpn': 0.7502389199999999, 'irreducibility': [0.0996, 0.0]}
# anchorSetProp0.01
# Sigma Shape Perturb
# Sigma Ratios: [1.25706834 1.        ]
# Sigma Ratios: [1.25706834 1.        ]
# isMetricSatisfied{'aucpn': 0.7303938799999999, 'irreducibility': [0.0208, 0.1292]}
# anchorSetProp0.01
# i loop
# aucs0.65341712
# irr_pos[0. 0.]
# irr_neg[0.001 0.055]
# first loop in j loop
# aucs0.76425312
# irr_pos[0.001 0.   ]
# irr_neg[0.002 0.04 ]
# first loop in j loop
# aucs0.8922430399999999
# irr_pos[0.014 0.002]
# irr_neg[0.021 0.045]
# first loop in j loop
# aucs0.97012768
# irr_pos[0.009 0.002]
# irr_neg[0.019 0.056]
# first loop in j loop
# aucs0.99486752
# irr_pos[0.009 0.001]
# irr_neg[0.032 0.059]
# first loop in j loop
# aucs0.99935696
# irr_pos[0.005 0.06 ]
# irr_neg[0.031 0.06 ]
# first loop in j loop
# aucs0.9999420800000001
# irr_pos[0.016 0.103]
# irr_neg[0.031 0.055]
# second loop in j loop
# aucs0.97271424
# irr_pos[0.006 0.002]
# irr_neg[0.033 0.061]
# second loop in j loop
# aucs0.99831664
# irr_pos[0.018 0.002]
# irr_neg[0.037 0.038]
# second loop in j loop
# aucs0.99959648
# irr_pos[0.01  0.081]
# irr_neg[0.04  0.042]
# second loop in j loop
# aucs0.9992526399999999
# irr_pos[0.012 0.03 ]
# irr_neg[0.029 0.053]
# second loop in j loop
# aucs0.99883856
# irr_pos[0.011 0.003]
# irr_neg[0.032 0.059]
# second loop in j loop
# aucs0.99924032
# irr_pos[0.02  0.022]
# irr_neg[0.025 0.055]
# second loop in j loop
# aucs0.9987663999999999
# irr_pos[0.018 0.015]
# irr_neg[0.037 0.047]
# second loop in j loop
# aucs0.998816
# irr_pos[0.017 0.016]
# irr_neg[0.036 0.047]
# second loop in j loop
# aucs0.99860752
# irr_pos[0.01 0.01]
# irr_neg[0.027 0.049]
# second loop in j loop
# aucs0.9990024000000001
# irr_pos[0.014 0.009]
# irr_neg[0.036 0.044]
# second loop in j loop
# aucs0.99872192
# irr_pos[0.013 0.004]
# irr_neg[0.033 0.054]
# second loop in j loop
# aucs0.99886448
# irr_pos[0.018 0.007]
# irr_neg[0.035 0.053]
# second loop in j loop
# aucs0.9986816000000001
# irr_pos[0.009 0.004]
# irr_neg[0.034 0.07 ]
# second loop in j loop
# aucs0.999064
# irr_pos[0.011 0.008]
# irr_neg[0.044 0.064]
# second loop in j loop
# aucs0.9987656
# irr_pos[0.014 0.014]
# irr_neg[0.03  0.054]
# second loop in j loop
# aucs0.9992559999999999
# irr_pos[0.014 0.012]
# irr_neg[0.04  0.052]
# second loop in j loop
# aucs0.9988523199999999
# irr_pos[0.011 0.004]
# irr_neg[0.031 0.056]
# after two j loops
# aucs0.9988523199999999
# irr_pos[0.011 0.004]
# irr_neg[0.031 0.056]
# first loop in j loop
# aucs0.59065744
# irr_pos[0.001 0.001]
# irr_neg[0.001 0.034]
# first loop in j loop
# aucs0.80268016
# irr_pos[0.002 0.031]
# irr_neg[0.    0.011]
# first loop in j loop
# aucs0.9068425599999999
# irr_pos[0.015 0.064]
# irr_neg[0.001 0.01 ]
# first loop in j loop
# aucs0.9691323199999999
# irr_pos[0.01  0.106]
# irr_neg[0.019 0.009]
# first loop in j loop
# aucs0.9945284799999999
# irr_pos[0.011 0.092]
# irr_neg[0.025 0.013]
# second loop in j loop
# aucs0.8961376
# irr_pos[0.01  0.045]
# irr_neg[0.004 0.007]
# second loop in j loop
# aucs0.968892
# irr_pos[0.016 0.113]
# irr_neg[0.012 0.011]
# second loop in j loop
# aucs0.9373668799999999
# irr_pos[0.008 0.068]
# irr_neg[0.004 0.007]
# second loop in j loop
# aucs0.9544968000000001
# irr_pos[0.016 0.088]
# irr_neg[0.008 0.008]
# second loop in j loop
# aucs0.95853776
# irr_pos[0.017 0.09 ]
# irr_neg[0.007 0.009]
# second loop in j loop
# aucs0.9635297599999999
# irr_pos[0.009 0.094]
# irr_neg[0.008 0.009]
# second loop in j loop
# aucs0.9656532800000001
# irr_pos[0.012 0.097]
# irr_neg[0.015 0.008]
# second loop in j loop
# aucs0.96669984
# irr_pos[0.012 0.085]
# irr_neg[0.019 0.004]
# second loop in j loop
# aucs0.96420672
# irr_pos[0.015 0.094]
# irr_neg[0.012 0.008]
# second loop in j loop
# aucs0.96539152
# irr_pos[0.013 0.104]
# irr_neg[0.019 0.012]
# second loop in j loop
# aucs0.9693833600000001
# irr_pos[0.011 0.085]
# irr_neg[0.01  0.012]
# second loop in j loop
# aucs0.9696272
# irr_pos[0.014 0.098]
# irr_neg[0.008 0.006]
# second loop in j loop
# aucs0.9632694399999999
# irr_pos[0.014 0.09 ]
# irr_neg[0.012 0.013]
# second loop in j loop
# aucs0.9655808000000001
# irr_pos[0.017 0.091]
# irr_neg[0.011 0.012]
# second loop in j loop
# aucs0.9701014400000001
# irr_pos[0.016 0.09 ]
# irr_neg[0.011 0.011]
# second loop in j loop
# aucs0.96991488
# irr_pos[0.009 0.087]
# irr_neg[0.013 0.004]
# second loop in j loop
# aucs0.9712572800000001
# irr_pos[0.014 0.071]
# irr_neg[0.018 0.004]
# after two j loops
# aucs0.9712572800000001
# irr_pos[0.014 0.071]
# irr_neg[0.018 0.004]
# first loop in j loop
# aucs0.7622441600000001
# irr_pos[0.001 0.001]
# irr_neg[0.002 0.061]
# first loop in j loop
# aucs0.8926744
# irr_pos[0.007 0.002]
# irr_neg[0.023 0.053]
# first loop in j loop
# aucs0.9706164799999999
# irr_pos[0.008 0.001]
# irr_neg[0.029 0.054]
# first loop in j loop
# aucs0.99451856
# irr_pos[0.014 0.003]
# irr_neg[0.04  0.058]
# first loop in j loop
# aucs0.99930368
# irr_pos[0.006 0.056]
# irr_neg[0.042 0.046]
# first loop in j loop
# aucs0.99994304
# irr_pos[0.019 0.109]
# irr_neg[0.04  0.056]
# second loop in j loop
# aucs0.96719792
# irr_pos[0.005 0.002]
# irr_neg[0.036 0.063]
# second loop in j loop
# aucs0.99830336
# irr_pos[0.013 0.   ]
# irr_neg[0.034 0.058]
# second loop in j loop
# aucs0.9996198399999999
# irr_pos[0.011 0.063]
# irr_neg[0.038 0.063]
# second loop in j loop
# aucs0.99906272
# irr_pos[0.014 0.034]
# irr_neg[0.048 0.05 ]
# second loop in j loop
# aucs0.9984208
# irr_pos[0.012 0.012]
# irr_neg[0.038 0.05 ]
# second loop in j loop
# aucs0.99843792
# irr_pos[0.016 0.005]
# irr_neg[0.041 0.048]
# second loop in j loop
# aucs0.99859488
# irr_pos[0.015 0.01 ]
# irr_neg[0.027 0.056]
# second loop in j loop
# aucs0.99841008
# irr_pos[0.016 0.005]
# irr_neg[0.047 0.048]
# second loop in j loop
# aucs0.99848592
# irr_pos[0.014 0.007]
# irr_neg[0.028 0.053]
# second loop in j loop
# aucs0.99866432
# irr_pos[0.013 0.004]
# irr_neg[0.04  0.049]
# second loop in j loop
# aucs0.99841552
# irr_pos[0.023 0.005]
# irr_neg[0.029 0.05 ]
# second loop in j loop
# aucs0.9983355199999999
# irr_pos[0.017 0.012]
# irr_neg[0.034 0.053]
# second loop in j loop
# aucs0.99865664
# irr_pos[0.018 0.011]
# irr_neg[0.046 0.063]
# second loop in j loop
# aucs0.998788
# irr_pos[0.01  0.007]
# irr_neg[0.036 0.054]
# second loop in j loop
# aucs0.99861024
# irr_pos[0.018 0.012]
# irr_neg[0.039 0.054]
# second loop in j loop
# aucs0.99868704
# irr_pos[0.016 0.004]
# irr_neg[0.038 0.058]
# second loop in j loop
# aucs0.9987928
# irr_pos[0.011 0.009]
# irr_neg[0.023 0.045]
# after two j loops
# aucs0.9987928
# irr_pos[0.011 0.009]
# irr_neg[0.023 0.045]
# first loop in j loop
# aucs0.59960864
# irr_pos[0.001 0.001]
# irr_neg[0.    0.026]
# first loop in j loop
# aucs0.81421936
# irr_pos[0.009 0.014]
# irr_neg[0.002 0.01 ]
# first loop in j loop
# aucs0.9205135999999999
# irr_pos[0.015 0.063]
# irr_neg[0.006 0.007]
# first loop in j loop
# aucs0.9759075200000001
# irr_pos[0.011 0.091]
# irr_neg[0.008 0.007]
# first loop in j loop
# aucs0.99495984
# irr_pos[0.012 0.107]
# irr_neg[0.021 0.007]
# first loop in j loop
# aucs0.99954272
# irr_pos[0.016 0.108]
# irr_neg[0.026 0.01 ]
# second loop in j loop
# aucs0.9418087999999999
# irr_pos[0.007 0.068]
# irr_neg[0.01  0.006]
# second loop in j loop
# aucs0.99284912
# irr_pos[0.015 0.098]
# irr_neg[0.012 0.004]
# second loop in j loop
# aucs0.997656
# irr_pos[0.01  0.107]
# irr_neg[0.031 0.005]
# second loop in j loop
# aucs0.9986472
# irr_pos[0.008 0.111]
# irr_neg[0.026 0.013]
# second loop in j loop
# aucs0.99946656
# irr_pos[0.013 0.1  ]
# irr_neg[0.023 0.013]
# second loop in j loop
# aucs0.9989782400000001
# irr_pos[0.013 0.11 ]
# irr_neg[0.031 0.004]
# second loop in j loop
# aucs0.9991283199999998
# irr_pos[0.012 0.121]
# irr_neg[0.03 0.01]
# second loop in j loop
# aucs0.9988712
# irr_pos[0.012 0.106]
# irr_neg[0.029 0.01 ]
# second loop in j loop
# aucs0.99930768
# irr_pos[0.009 0.122]
# irr_neg[0.038 0.012]
# second loop in j loop
# aucs0.99906784
# irr_pos[0.015 0.096]
# irr_neg[0.018 0.002]
# second loop in j loop
# aucs0.99917664
# irr_pos[0.01  0.124]
# irr_neg[0.027 0.014]
# second loop in j loop
# aucs0.99883552
# irr_pos[0.014 0.122]
# irr_neg[0.027 0.009]
# second loop in j loop
# aucs0.99869392
# irr_pos[0.014 0.121]
# irr_neg[0.035 0.003]
# second loop in j loop
# aucs0.9991595199999999
# irr_pos[0.01  0.116]
# irr_neg[0.036 0.012]
# second loop in j loop
# aucs0.99904672
# irr_pos[0.01  0.099]
# irr_neg[0.031 0.004]
# second loop in j loop
# aucs0.9990742400000001
# irr_pos[0.011 0.117]
# irr_neg[0.028 0.008]
# second loop in j loop
# aucs0.99885744
# irr_pos[0.013 0.098]
# irr_neg[0.041 0.006]
# after two j loops
# aucs0.99885744
# irr_pos[0.013 0.098]
# irr_neg[0.041 0.006]
# first loop in j loop
# aucs0.59901936
# irr_pos[0.003 0.001]
# irr_neg[0.   0.03]
# first loop in j loop
# aucs0.8417622400000001
# irr_pos[0.013 0.011]
# irr_neg[0.003 0.018]
# first loop in j loop
# aucs0.9620312000000001
# irr_pos[0.011 0.053]
# irr_neg[0.009 0.009]
# first loop in j loop
# aucs0.99374752
# irr_pos[0.013 0.099]
# irr_neg[0.018 0.01 ]
# second loop in j loop
# aucs0.8912366399999999
# irr_pos[0.006 0.029]
# irr_neg[0.003 0.013]
# second loop in j loop
# aucs0.96161552
# irr_pos[0.011 0.061]
# irr_neg[0.017 0.009]
# second loop in j loop
# aucs0.9835731200000001
# irr_pos[0.009 0.076]
# irr_neg[0.018 0.008]
# second loop in j loop
# aucs0.9886588800000001
# irr_pos[0.011 0.097]
# irr_neg[0.028 0.007]
# second loop in j loop
# aucs0.99184384
# irr_pos[0.012 0.083]
# irr_neg[0.023 0.002]
# second loop in j loop
# aucs0.9913916800000001
# irr_pos[0.011 0.103]
# irr_neg[0.031 0.012]
# second loop in j loop
# aucs0.99202944
# irr_pos[0.017 0.068]
# irr_neg[0.027 0.006]
# second loop in j loop
# aucs0.99188848
# irr_pos[0.019 0.082]
# irr_neg[0.018 0.018]
# second loop in j loop
# aucs0.99130992
# irr_pos[0.009 0.085]
# irr_neg[0.024 0.006]
# second loop in j loop
# aucs0.9921044800000002
# irr_pos[0.012 0.082]
# irr_neg[0.026 0.01 ]
# second loop in j loop
# aucs0.9911990400000001
# irr_pos[0.011 0.075]
# irr_neg[0.022 0.007]
# second loop in j loop
# aucs0.9909278400000001
# irr_pos[0.015 0.069]
# irr_neg[0.02  0.008]
# second loop in j loop
# aucs0.9915617600000001
# irr_pos[0.01  0.093]
# irr_neg[0.024 0.007]
# second loop in j loop
# aucs0.99302272
# irr_pos[0.01  0.098]
# irr_neg[0.017 0.003]
# second loop in j loop
# aucs0.9911825599999999
# irr_pos[0.018 0.099]
# irr_neg[0.025 0.007]
# second loop in j loop
# aucs0.99094032
# irr_pos[0.02  0.074]
# irr_neg[0.023 0.009]
# second loop in j loop
# aucs0.9919683200000001
# irr_pos[0.012 0.092]
# irr_neg[0.026 0.011]
# after two j loops
# aucs0.9919683200000001
# irr_pos[0.012 0.092]
# irr_neg[0.026 0.011]
# after j loops
# aucs0.9676838400000001
# irr_pos[0.016 0.098]
# irr_neg[0.009 0.005]
# i loop
# aucs0.6730064
# irr_pos[0.    0.097 0.   ]
# irr_neg[0.002 0.009 0.018]
# first loop in j loop
# aucs0.68285936
# irr_pos[0.    0.079 0.   ]
# irr_neg[0.    0.008 0.022]
# first loop in j loop
# aucs0.87130288
# irr_pos[0.    0.085 0.   ]
# irr_neg[0.002 0.004 0.017]
# first loop in j loop
# aucs0.9728121599999999
# irr_pos[0.   0.08 0.  ]
# irr_neg[0.001 0.008 0.015]
# first loop in j loop
# aucs0.99687152
# irr_pos[0.    0.092 0.003]
# irr_neg[0.    0.008 0.027]
# first loop in j loop
# aucs0.99949488
# irr_pos[0.008 0.095 0.015]
# irr_neg[0.003 0.008 0.017]
# first loop in j loop
# aucs0.99998304
# irr_pos[0.009 0.083 0.013]
# irr_neg[0.008 0.008 0.017]
# first loop in j loop
# aucs0.99999936
# irr_pos[0.014 0.084 0.023]
# irr_neg[0.011 0.007 0.024]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.098 0.023]
# irr_neg[0.016 0.005 0.012]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.09  0.022]
# irr_neg[0.012 0.006 0.017]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.097 0.022]
# irr_neg[0.009 0.01  0.026]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.107 0.024]
# irr_neg[0.018 0.006 0.025]
# first loop in j loop
# aucs1.0
# irr_pos[0.011 0.106 0.023]
# irr_neg[0.005 0.008 0.02 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.019 0.085 0.026]
# irr_neg[0.011 0.009 0.02 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.007 0.081 0.021]
# irr_neg[0.01  0.008 0.027]
# first loop in j loop
# aucs1.0
# irr_pos[0.017 0.086 0.024]
# irr_neg[0.013 0.011 0.016]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.106 0.027]
# irr_neg[0.007 0.009 0.015]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.089 0.019]
# irr_neg[0.015 0.014 0.029]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.072 0.015]
# irr_neg[0.015 0.008 0.021]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.086 0.037]
# irr_neg[0.014 0.012 0.017]
# second loop in j loop
# aucs1.0
# irr_pos[0.016 0.087 0.017]
# irr_neg[0.009 0.011 0.018]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.103 0.018]
# irr_neg[0.013 0.009 0.016]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.09  0.021]
# irr_neg[0.007 0.009 0.021]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.074 0.017]
# irr_neg[0.01  0.012 0.024]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.094 0.016]
# irr_neg[0.009 0.004 0.021]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.091 0.024]
# irr_neg[0.004 0.006 0.02 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.098 0.024]
# irr_neg[0.013 0.006 0.017]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.094 0.021]
# irr_neg[0.013 0.008 0.023]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.083 0.022]
# irr_neg[0.016 0.01  0.022]
# second loop in j loop
# aucs1.0
# irr_pos[0.008 0.082 0.018]
# irr_neg[0.012 0.01  0.012]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.074 0.025]
# irr_neg[0.006 0.01  0.027]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.089 0.02 ]
# irr_neg[0.015 0.01  0.014]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.083 0.025]
# irr_neg[0.017 0.007 0.025]
# after two j loops
# aucs1.0
# irr_pos[0.015 0.083 0.025]
# irr_neg[0.017 0.007 0.025]
# first loop in j loop
# aucs0.8820960000000001
# irr_pos[0.    0.079 0.   ]
# irr_neg[0.011 0.009 0.02 ]
# first loop in j loop
# aucs0.9734257600000003
# irr_pos[0.    0.099 0.   ]
# irr_neg[0.012 0.018 0.017]
# first loop in j loop
# aucs0.9967449600000001
# irr_pos[0.005 0.087 0.002]
# irr_neg[0.007 0.006 0.02 ]
# first loop in j loop
# aucs0.9995448
# irr_pos[0.008 0.086 0.009]
# irr_neg[0.014 0.004 0.022]
# first loop in j loop
# aucs0.9999512
# irr_pos[0.009 0.096 0.022]
# irr_neg[0.015 0.009 0.023]
# first loop in j loop
# aucs0.9999992
# irr_pos[0.02  0.106 0.016]
# irr_neg[0.016 0.004 0.031]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.103 0.016]
# irr_neg[0.014 0.006 0.02 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.071 0.022]
# irr_neg[0.017 0.006 0.031]
# first loop in j loop
# aucs1.0
# irr_pos[0.007 0.096 0.018]
# irr_neg[0.012 0.013 0.023]
# first loop in j loop
# aucs1.0
# irr_pos[0.007 0.085 0.024]
# irr_neg[0.012 0.009 0.013]
# first loop in j loop
# aucs1.0
# irr_pos[0.023 0.084 0.033]
# irr_neg[0.009 0.013 0.021]
# first loop in j loop
# aucs1.0
# irr_pos[0.009 0.097 0.017]
# irr_neg[0.009 0.01  0.028]
# first loop in j loop
# aucs1.0
# irr_pos[0.009 0.082 0.022]
# irr_neg[0.011 0.01  0.018]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.092 0.017]
# irr_neg[0.011 0.008 0.018]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.101 0.017]
# irr_neg[0.009 0.011 0.019]
# first loop in j loop
# aucs1.0
# irr_pos[0.008 0.099 0.017]
# irr_neg[0.009 0.002 0.019]
# first loop in j loop
# aucs1.0
# irr_pos[0.017 0.09  0.028]
# irr_neg[0.01  0.007 0.016]
# first loop in j loop
# aucs1.0
# irr_pos[0.018 0.099 0.024]
# irr_neg[0.015 0.008 0.021]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.102 0.014]
# irr_neg[0.014 0.014 0.021]
# second loop in j loop
# aucs1.0
# irr_pos[0.02  0.089 0.027]
# irr_neg[0.012 0.01  0.022]
# second loop in j loop
# aucs0.999544
# irr_pos[0.017 0.071 0.013]
# irr_neg[0.012 0.005 0.022]
# second loop in j loop
# aucs0.9999998400000001
# irr_pos[0.012 0.08  0.014]
# irr_neg[0.02  0.006 0.026]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.073 0.012]
# irr_neg[0.013 0.008 0.022]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.108 0.024]
# irr_neg[0.011 0.012 0.017]
# second loop in j loop
# aucs1.0
# irr_pos[0.007 0.098 0.033]
# irr_neg[0.01  0.009 0.015]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.1   0.018]
# irr_neg[0.012 0.005 0.012]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.083 0.022]
# irr_neg[0.012 0.012 0.018]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.092 0.026]
# irr_neg[0.008 0.007 0.017]
# second loop in j loop
# aucs1.0
# irr_pos[0.007 0.092 0.02 ]
# irr_neg[0.009 0.002 0.028]
# second loop in j loop
# aucs1.0
# irr_pos[0.018 0.102 0.022]
# irr_neg[0.011 0.01  0.026]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.094 0.022]
# irr_neg[0.011 0.007 0.019]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.09  0.015]
# irr_neg[0.01  0.007 0.024]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.085 0.02 ]
# irr_neg[0.01  0.012 0.017]
# second loop in j loop
# aucs1.0
# irr_pos[0.003 0.085 0.023]
# irr_neg[0.011 0.007 0.022]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.093 0.021]
# irr_neg[0.01  0.008 0.022]
# second loop in j loop
# aucs1.0
# irr_pos[0.006 0.098 0.024]
# irr_neg[0.014 0.013 0.018]
# after two j loops
# aucs1.0
# irr_pos[0.006 0.098 0.024]
# irr_neg[0.014 0.013 0.018]
# first loop in j loop
# aucs0.84250448
# irr_pos[0.    0.089 0.   ]
# irr_neg[0.007 0.01  0.009]
# first loop in j loop
# aucs0.9478983999999999
# irr_pos[0.005 0.087 0.001]
# irr_neg[0.013 0.013 0.011]
# first loop in j loop
# aucs0.9858769600000001
# irr_pos[0.013 0.095 0.013]
# irr_neg[0.008 0.007 0.015]
# first loop in j loop
# aucs0.99745408
# irr_pos[0.013 0.076 0.016]
# irr_neg[0.009 0.005 0.013]
# first loop in j loop
# aucs0.99980096
# irr_pos[0.013 0.097 0.015]
# irr_neg[0.013 0.011 0.017]
# second loop in j loop
# aucs0.9678369600000001
# irr_pos[0.023 0.063 0.02 ]
# irr_neg[0.019 0.009 0.   ]
# second loop in j loop
# aucs0.9965312
# irr_pos[0.009 0.096 0.022]
# irr_neg[0.01  0.006 0.007]
# second loop in j loop
# aucs0.9987872
# irr_pos[0.015 0.067 0.016]
# irr_neg[0.011 0.014 0.016]
# second loop in j loop
# aucs0.99786
# irr_pos[0.018 0.108 0.018]
# irr_neg[0.008 0.005 0.008]
# second loop in j loop
# aucs0.9985137599999999
# irr_pos[0.016 0.089 0.017]
# irr_neg[0.017 0.013 0.01 ]
# second loop in j loop
# aucs0.99864432
# irr_pos[0.013 0.085 0.019]
# irr_neg[0.012 0.005 0.006]
# second loop in j loop
# aucs0.9984513599999999
# irr_pos[0.011 0.093 0.019]
# irr_neg[0.008 0.005 0.014]
# second loop in j loop
# aucs0.99854656
# irr_pos[0.016 0.084 0.028]
# irr_neg[0.005 0.009 0.015]
# second loop in j loop
# aucs0.9984603200000001
# irr_pos[0.012 0.086 0.02 ]
# irr_neg[0.015 0.008 0.01 ]
# second loop in j loop
# aucs0.99852976
# irr_pos[0.016 0.085 0.029]
# irr_neg[0.015 0.004 0.009]
# second loop in j loop
# aucs0.9982704
# irr_pos[0.006 0.106 0.019]
# irr_neg[0.017 0.009 0.009]
# second loop in j loop
# aucs0.9985854399999999
# irr_pos[0.014 0.087 0.018]
# irr_neg[0.011 0.01  0.006]
# second loop in j loop
# aucs0.9983132800000001
# irr_pos[0.013 0.103 0.018]
# irr_neg[0.012 0.003 0.014]
# second loop in j loop
# aucs0.9990155200000002
# irr_pos[0.006 0.093 0.017]
# irr_neg[0.009 0.009 0.012]
# second loop in j loop
# aucs0.99839072
# irr_pos[0.013 0.094 0.01 ]
# irr_neg[0.007 0.011 0.007]
# second loop in j loop
# aucs0.99890448
# irr_pos[0.017 0.101 0.022]
# irr_neg[0.011 0.007 0.013]
# second loop in j loop
# aucs0.9980967999999999
# irr_pos[0.016 0.105 0.025]
# irr_neg[0.009 0.014 0.013]
# after two j loops
# aucs0.9980967999999999
# irr_pos[0.016 0.105 0.025]
# irr_neg[0.009 0.014 0.013]
# first loop in j loop
# aucs0.66133008
# irr_pos[0.    0.092 0.   ]
# irr_neg[0.    0.008 0.022]
# first loop in j loop
# aucs0.8775414399999999
# irr_pos[0.    0.078 0.   ]
# irr_neg[0.002 0.008 0.021]
# first loop in j loop
# aucs0.96711936
# irr_pos[0.    0.099 0.   ]
# irr_neg[0.001 0.005 0.019]
# first loop in j loop
# aucs0.9929560000000001
# irr_pos[0.001 0.097 0.009]
# irr_neg[0.003 0.01  0.021]
# first loop in j loop
# aucs0.9989822400000001
# irr_pos[0.009 0.099 0.017]
# irr_neg[0.    0.008 0.015]
# first loop in j loop
# aucs0.99995408
# irr_pos[0.009 0.08  0.018]
# irr_neg[0.002 0.009 0.027]
# first loop in j loop
# aucs0.9999950400000001
# irr_pos[0.009 0.073 0.02 ]
# irr_neg[0.007 0.008 0.02 ]
# first loop in j loop
# aucs0.99999936
# irr_pos[0.014 0.104 0.019]
# irr_neg[0.011 0.015 0.021]
# second loop in j loop
# aucs0.9945558399999999
# irr_pos[0.003 0.083 0.004]
# irr_neg[0.001 0.009 0.018]
# second loop in j loop
# aucs0.9999531199999999
# irr_pos[0.012 0.088 0.026]
# irr_neg[0.005 0.005 0.024]
# second loop in j loop
# aucs0.99999472
# irr_pos[0.013 0.102 0.015]
# irr_neg[0.005 0.012 0.024]
# second loop in j loop
# aucs0.9999998400000001
# irr_pos[0.016 0.097 0.019]
# irr_neg[0.016 0.007 0.012]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.099 0.024]
# irr_neg[0.009 0.011 0.019]
# second loop in j loop
# aucs1.0
# irr_pos[0.008 0.11  0.021]
# irr_neg[0.016 0.012 0.022]
# second loop in j loop
# aucs0.9999984000000001
# irr_pos[0.012 0.097 0.019]
# irr_neg[0.013 0.008 0.018]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.089 0.029]
# irr_neg[0.016 0.004 0.017]
# second loop in j loop
# aucs0.99999872
# irr_pos[0.011 0.086 0.021]
# irr_neg[0.012 0.007 0.024]
# second loop in j loop
# aucs1.0
# irr_pos[0.007 0.113 0.024]
# irr_neg[0.011 0.01  0.025]
# second loop in j loop
# aucs0.9999992
# irr_pos[0.013 0.084 0.021]
# irr_neg[0.012 0.008 0.016]
# second loop in j loop
# aucs1.0
# irr_pos[0.021 0.087 0.023]
# irr_neg[0.006 0.008 0.026]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.095 0.019]
# irr_neg[0.007 0.007 0.015]
# second loop in j loop
# aucs0.9999998400000001
# irr_pos[0.012 0.091 0.027]
# irr_neg[0.017 0.006 0.017]
# second loop in j loop
# aucs0.99999936
# irr_pos[0.011 0.082 0.024]
# irr_neg[0.01  0.007 0.022]
# second loop in j loop
# aucs0.9999998400000001
# irr_pos[0.015 0.086 0.016]
# irr_neg[0.015 0.009 0.023]
# second loop in j loop
# aucs0.9999998400000001
# irr_pos[0.008 0.093 0.018]
# irr_neg[0.014 0.007 0.021]
# after two j loops
# aucs0.9999998400000001
# irr_pos[0.008 0.093 0.018]
# irr_neg[0.014 0.007 0.021]
# first loop in j loop
# aucs0.71964688
# irr_pos[0.    0.076 0.   ]
# irr_neg[0.001 0.005 0.026]
# first loop in j loop
# aucs0.9035358400000001
# irr_pos[0.    0.094 0.   ]
# irr_neg[0.    0.006 0.025]
# first loop in j loop
# aucs0.9764788799999999
# irr_pos[0.   0.09 0.  ]
# irr_neg[0.002 0.008 0.022]
# first loop in j loop
# aucs0.99759424
# irr_pos[0.    0.073 0.001]
# irr_neg[0.006 0.007 0.027]
# first loop in j loop
# aucs0.99985952
# irr_pos[0.    0.077 0.006]
# irr_neg[0.01  0.011 0.023]
# first loop in j loop
# aucs0.9999935999999999
# irr_pos[0.01  0.098 0.03 ]
# irr_neg[0.016 0.008 0.019]
# first loop in j loop
# aucs0.9999998400000001
# irr_pos[0.012 0.084 0.009]
# irr_neg[0.016 0.009 0.019]
# first loop in j loop
# aucs1.0
# irr_pos[0.014 0.103 0.023]
# irr_neg[0.016 0.014 0.022]
# second loop in j loop
# aucs0.99647696
# irr_pos[0.    0.104 0.004]
# irr_neg[0.006 0.009 0.02 ]
# second loop in j loop
# aucs0.99999376
# irr_pos[0.01  0.099 0.025]
# irr_neg[0.013 0.011 0.017]
# second loop in j loop
# aucs0.99974064
# irr_pos[0.002 0.081 0.014]
# irr_neg[0.014 0.008 0.015]
# second loop in j loop
# aucs0.9999798400000001
# irr_pos[0.007 0.095 0.015]
# irr_neg[0.005 0.014 0.017]
# second loop in j loop
# aucs0.9999852800000001
# irr_pos[0.01  0.077 0.017]
# irr_neg[0.01  0.01  0.019]
# second loop in j loop
# aucs0.99998592
# irr_pos[0.005 0.088 0.018]
# irr_neg[0.01  0.015 0.022]
# second loop in j loop
# aucs0.9999895999999999
# irr_pos[0.015 0.092 0.014]
# irr_neg[0.009 0.012 0.021]
# second loop in j loop
# aucs0.99992912
# irr_pos[0.004 0.093 0.014]
# irr_neg[0.008 0.006 0.018]
# second loop in j loop
# aucs0.99999392
# irr_pos[0.013 0.09  0.008]
# irr_neg[0.006 0.01  0.013]
# second loop in j loop
# aucs0.99993728
# irr_pos[0.011 0.093 0.016]
# irr_neg[0.012 0.007 0.017]
# second loop in j loop
# aucs0.9999832000000001
# irr_pos[0.008 0.09  0.012]
# irr_neg[0.009 0.006 0.023]
# second loop in j loop
# aucs0.99997216
# irr_pos[0.008 0.081 0.017]
# irr_neg[0.01  0.009 0.024]
# second loop in j loop
# aucs0.9999784
# irr_pos[0.007 0.096 0.014]
# irr_neg[0.01  0.01  0.013]
# second loop in j loop
# aucs0.99998384
# irr_pos[0.01  0.089 0.01 ]
# irr_neg[0.009 0.005 0.028]
# second loop in j loop
# aucs0.99998416
# irr_pos[0.01  0.103 0.018]
# irr_neg[0.011 0.008 0.021]
# second loop in j loop
# aucs0.9999688
# irr_pos[0.012 0.082 0.018]
# irr_neg[0.009 0.002 0.023]
# second loop in j loop
# aucs0.9999798400000001
# irr_pos[0.012 0.09  0.013]
# irr_neg[0.008 0.011 0.018]
# after two j loops
# aucs0.9999798400000001
# irr_pos[0.012 0.09  0.013]
# irr_neg[0.008 0.011 0.018]
# after j loops
# aucs0.99818176
# irr_pos[0.013 0.084 0.022]
# irr_neg[0.014 0.006 0.014]
# i loop
# aucs0.65112976
# irr_pos[0.    0.069 0.033 0.   ]
# irr_neg[0.    0.017 0.013 0.017]
# first loop in j loop
# aucs0.70367904
# irr_pos[0.003 0.078 0.018 0.   ]
# irr_neg[0.005 0.007 0.008 0.019]
# first loop in j loop
# aucs0.89428256
# irr_pos[0.006 0.083 0.018 0.   ]
# irr_neg[0.018 0.012 0.002 0.011]
# first loop in j loop
# aucs0.9296243200000001
# irr_pos[0.012 0.094 0.017 0.   ]
# irr_neg[0.015 0.009 0.    0.   ]
# first loop in j loop
# aucs0.7909649599999999
# irr_pos[0.009 0.101 0.006 0.   ]
# irr_neg[0.012 0.009 0.    0.   ]
# first loop in j loop
# aucs0.6485592
# irr_pos[0.012 0.093 0.    0.   ]
# irr_neg[0.018 0.007 0.    0.   ]
# first loop in j loop
# aucs0.7768209599999999
# irr_pos[0.015 0.082 0.    0.004]
# irr_neg[0.008 0.009 0.009 0.   ]
# first loop in j loop
# aucs0.9450035200000001
# irr_pos[0.016 0.096 0.    0.022]
# irr_neg[0.011 0.008 0.006 0.018]
# first loop in j loop
# aucs0.9925782400000001
# irr_pos[0.009 0.101 0.001 0.017]
# irr_neg[0.012 0.013 0.013 0.088]
# first loop in j loop
# aucs0.99937744
# irr_pos[0.006 0.082 0.004 0.026]
# irr_neg[0.009 0.009 0.01  0.111]
# first loop in j loop
# aucs0.99995888
# irr_pos[0.012 0.096 0.016 0.025]
# irr_neg[0.011 0.002 0.013 0.137]
# first loop in j loop
# aucs0.99999856
# irr_pos[0.007 0.09  0.025 0.022]
# irr_neg[0.01  0.008 0.011 0.125]
# first loop in j loop
# aucs0.9999998400000001
# irr_pos[0.013 0.106 0.025 0.019]
# irr_neg[0.011 0.008 0.011 0.13 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.008 0.092 0.016 0.024]
# irr_neg[0.012 0.01  0.009 0.131]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.085 0.023 0.027]
# irr_neg[0.008 0.012 0.013 0.138]
# first loop in j loop
# aucs1.0
# irr_pos[0.008 0.092 0.014 0.023]
# irr_neg[0.008 0.009 0.015 0.133]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.098 0.019 0.03 ]
# irr_neg[0.013 0.01  0.005 0.136]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.106 0.024 0.023]
# irr_neg[0.008 0.01  0.013 0.118]
# first loop in j loop
# aucs1.0
# irr_pos[0.011 0.084 0.021 0.016]
# irr_neg[0.007 0.009 0.008 0.15 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.007 0.097 0.02  0.014]
# irr_neg[0.016 0.016 0.01  0.128]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.09  0.018 0.017]
# irr_neg[0.012 0.01  0.018 0.124]
# second loop in j loop
# aucs0.99998336
# irr_pos[0.014 0.089 0.011 0.026]
# irr_neg[0.01  0.007 0.016 0.133]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.09  0.017 0.018]
# irr_neg[0.018 0.008 0.011 0.121]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.078 0.019 0.019]
# irr_neg[0.014 0.007 0.012 0.123]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.088 0.02  0.029]
# irr_neg[0.009 0.004 0.013 0.138]
# second loop in j loop
# aucs1.0
# irr_pos[0.017 0.097 0.019 0.017]
# irr_neg[0.014 0.008 0.012 0.15 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.017 0.081 0.016 0.026]
# irr_neg[0.006 0.011 0.009 0.143]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.103 0.016 0.026]
# irr_neg[0.017 0.013 0.015 0.12 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.086 0.017 0.02 ]
# irr_neg[0.005 0.007 0.012 0.125]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.067 0.016 0.021]
# irr_neg[0.013 0.007 0.019 0.122]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.1   0.023 0.02 ]
# irr_neg[0.007 0.008 0.013 0.124]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.087 0.018 0.02 ]
# irr_neg[0.013 0.01  0.009 0.114]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.099 0.021 0.018]
# irr_neg[0.007 0.009 0.01  0.129]
# second loop in j loop
# aucs1.0
# irr_pos[0.022 0.094 0.018 0.021]
# irr_neg[0.019 0.007 0.009 0.12 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.006 0.084 0.02  0.021]
# irr_neg[0.012 0.007 0.004 0.119]
# second loop in j loop
# aucs1.0
# irr_pos[0.008 0.1   0.02  0.02 ]
# irr_neg[0.011 0.011 0.01  0.131]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.101 0.022 0.019]
# irr_neg[0.009 0.008 0.009 0.145]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.091 0.021 0.024]
# irr_neg[0.01  0.011 0.006 0.129]
# after two j loops
# aucs1.0
# irr_pos[0.009 0.091 0.021 0.024]
# irr_neg[0.01  0.011 0.006 0.129]
# first loop in j loop
# aucs0.7553368
# irr_pos[0.    0.083 0.02  0.   ]
# irr_neg[0.    0.005 0.012 0.103]
# first loop in j loop
# aucs0.92054656
# irr_pos[0.    0.093 0.024 0.002]
# irr_neg[0.003 0.004 0.015 0.118]
# first loop in j loop
# aucs0.98836496
# irr_pos[0.    0.085 0.018 0.002]
# irr_neg[0.013 0.006 0.013 0.141]
# first loop in j loop
# aucs0.99922224
# irr_pos[0.    0.085 0.02  0.001]
# irr_neg[0.008 0.004 0.015 0.146]
# first loop in j loop
# aucs0.99988784
# irr_pos[0.    0.076 0.021 0.019]
# irr_neg[0.01  0.007 0.01  0.138]
# first loop in j loop
# aucs0.9999982399999999
# irr_pos[0.006 0.083 0.018 0.025]
# irr_neg[0.009 0.008 0.009 0.125]
# first loop in j loop
# aucs1.0
# irr_pos[0.009 0.105 0.018 0.027]
# irr_neg[0.013 0.005 0.011 0.123]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.079 0.016 0.028]
# irr_neg[0.015 0.009 0.017 0.137]
# first loop in j loop
# aucs1.0
# irr_pos[0.014 0.092 0.02  0.021]
# irr_neg[0.012 0.005 0.012 0.132]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.083 0.012 0.017]
# irr_neg[0.012 0.01  0.009 0.119]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.102 0.021 0.024]
# irr_neg[0.013 0.006 0.015 0.118]
# first loop in j loop
# aucs1.0
# irr_pos[0.007 0.078 0.021 0.019]
# irr_neg[0.007 0.016 0.013 0.139]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.077 0.017 0.019]
# irr_neg[0.008 0.004 0.015 0.132]
# first loop in j loop
# aucs1.0
# irr_pos[0.011 0.084 0.021 0.02 ]
# irr_neg[0.009 0.005 0.004 0.121]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.083 0.016 0.016]
# irr_neg[0.009 0.009 0.013 0.128]
# first loop in j loop
# aucs1.0
# irr_pos[0.018 0.09  0.017 0.025]
# irr_neg[0.005 0.014 0.017 0.138]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.092 0.019 0.018]
# irr_neg[0.005 0.014 0.011 0.14 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.083 0.023 0.032]
# irr_neg[0.012 0.007 0.007 0.121]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.075 0.02  0.019]
# irr_neg[0.014 0.01  0.011 0.14 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.088 0.015 0.023]
# irr_neg[0.011 0.006 0.014 0.133]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.083 0.016 0.009]
# irr_neg[0.013 0.01  0.013 0.129]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.094 0.02  0.021]
# irr_neg[0.012 0.006 0.01  0.135]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.088 0.014 0.021]
# irr_neg[0.01  0.01  0.009 0.109]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.08  0.027 0.033]
# irr_neg[0.007 0.008 0.01  0.117]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.091 0.022 0.017]
# irr_neg[0.006 0.009 0.011 0.126]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.09  0.028 0.026]
# irr_neg[0.011 0.007 0.008 0.134]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.086 0.022 0.027]
# irr_neg[0.01  0.011 0.012 0.125]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.082 0.022 0.017]
# irr_neg[0.007 0.009 0.014 0.142]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.095 0.021 0.025]
# irr_neg[0.005 0.01  0.012 0.134]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.101 0.018 0.024]
# irr_neg[0.01  0.007 0.009 0.13 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.008 0.091 0.022 0.019]
# irr_neg[0.014 0.012 0.014 0.115]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.085 0.019 0.023]
# irr_neg[0.01  0.01  0.015 0.123]
# second loop in j loop
# aucs1.0
# irr_pos[0.017 0.104 0.024 0.023]
# irr_neg[0.01  0.008 0.012 0.13 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.1   0.026 0.017]
# irr_neg[0.012 0.007 0.011 0.133]
# second loop in j loop
# aucs1.0
# irr_pos[0.008 0.09  0.021 0.021]
# irr_neg[0.012 0.008 0.014 0.14 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.076 0.021 0.02 ]
# irr_neg[0.009 0.012 0.005 0.12 ]
# after two j loops
# aucs1.0
# irr_pos[0.014 0.076 0.021 0.02 ]
# irr_neg[0.009 0.012 0.005 0.12 ]
# first loop in j loop
# aucs0.6406521599999999
# irr_pos[0.    0.073 0.02  0.   ]
# irr_neg[0.    0.005 0.009 0.   ]
# first loop in j loop
# aucs0.79077536
# irr_pos[0.017 0.042 0.019 0.   ]
# irr_neg[0.002 0.013 0.008 0.   ]
# first loop in j loop
# aucs0.69099472
# irr_pos[0.017 0.047 0.011 0.001]
# irr_neg[0.006 0.008 0.007 0.   ]
# first loop in j loop
# aucs0.8026614399999998
# irr_pos[0.015 0.063 0.021 0.009]
# irr_neg[0.009 0.002 0.008 0.   ]
# first loop in j loop
# aucs0.9344656
# irr_pos[0.009 0.083 0.017 0.028]
# irr_neg[0.009 0.    0.016 0.   ]
# first loop in j loop
# aucs0.9874327999999999
# irr_pos[0.012 0.092 0.008 0.019]
# irr_neg[0.016 0.    0.011 0.   ]
# first loop in j loop
# aucs0.99871008
# irr_pos[0.015 0.083 0.012 0.017]
# irr_neg[0.01  0.    0.007 0.069]
# first loop in j loop
# aucs0.9999104
# irr_pos[0.004 0.097 0.006 0.018]
# irr_neg[0.011 0.    0.012 0.104]
# first loop in j loop
# aucs0.99998752
# irr_pos[0.016 0.103 0.006 0.023]
# irr_neg[0.013 0.005 0.016 0.115]
# first loop in j loop
# aucs1.0
# irr_pos[0.011 0.066 0.011 0.021]
# irr_neg[0.005 0.005 0.012 0.14 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.097 0.016 0.021]
# irr_neg[0.014 0.008 0.006 0.12 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.006 0.101 0.023 0.018]
# irr_neg[0.006 0.009 0.011 0.136]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.096 0.023 0.023]
# irr_neg[0.009 0.009 0.008 0.136]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.079 0.021 0.026]
# irr_neg[0.01  0.008 0.012 0.121]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.103 0.023 0.03 ]
# irr_neg[0.011 0.007 0.012 0.133]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.092 0.016 0.022]
# irr_neg[0.013 0.009 0.009 0.14 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.011 0.088 0.023 0.021]
# irr_neg[0.016 0.002 0.008 0.118]
# first loop in j loop
# aucs1.0
# irr_pos[0.014 0.082 0.015 0.021]
# irr_neg[0.004 0.008 0.012 0.127]
# first loop in j loop
# aucs1.0
# irr_pos[0.013 0.095 0.026 0.021]
# irr_neg[0.018 0.008 0.007 0.131]
# first loop in j loop
# aucs1.0
# irr_pos[0.016 0.097 0.016 0.024]
# irr_neg[0.006 0.012 0.013 0.131]
# first loop in j loop
# aucs1.0
# irr_pos[0.014 0.09  0.026 0.023]
# irr_neg[0.008 0.011 0.012 0.132]
# first loop in j loop
# aucs1.0
# irr_pos[0.015 0.077 0.017 0.023]
# irr_neg[0.013 0.01  0.013 0.124]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.081 0.021 0.019]
# irr_neg[0.006 0.01  0.009 0.12 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.021 0.091 0.019 0.024]
# irr_neg[0.015 0.013 0.009 0.133]
# second loop in j loop
# aucs1.0
# irr_pos[0.016 0.093 0.023 0.018]
# irr_neg[0.014 0.004 0.017 0.126]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.086 0.023 0.022]
# irr_neg[0.009 0.009 0.019 0.136]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.107 0.015 0.021]
# irr_neg[0.012 0.006 0.01  0.123]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.081 0.018 0.028]
# irr_neg[0.011 0.011 0.012 0.122]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.099 0.021 0.018]
# irr_neg[0.016 0.008 0.017 0.128]
# second loop in j loop
# aucs1.0
# irr_pos[0.019 0.089 0.018 0.02 ]
# irr_neg[0.01  0.011 0.007 0.131]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.099 0.016 0.027]
# irr_neg[0.013 0.008 0.011 0.121]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.089 0.019 0.031]
# irr_neg[0.015 0.004 0.012 0.153]
# second loop in j loop
# aucs1.0
# irr_pos[0.016 0.088 0.01  0.009]
# irr_neg[0.005 0.007 0.016 0.137]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.087 0.016 0.03 ]
# irr_neg[0.007 0.006 0.007 0.142]
# second loop in j loop
# aucs1.0
# irr_pos[0.019 0.085 0.024 0.018]
# irr_neg[0.009 0.01  0.013 0.12 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.081 0.015 0.021]
# irr_neg[0.007 0.008 0.005 0.132]
# second loop in j loop
# aucs1.0
# irr_pos[0.018 0.088 0.027 0.019]
# irr_neg[0.01  0.008 0.009 0.147]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.083 0.018 0.025]
# irr_neg[0.006 0.005 0.009 0.133]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.09  0.025 0.034]
# irr_neg[0.012 0.008 0.01  0.124]
# after two j loops
# aucs1.0
# irr_pos[0.009 0.09  0.025 0.034]
# irr_neg[0.012 0.008 0.01  0.124]
# first loop in j loop
# aucs0.6657384
# irr_pos[0.001 0.065 0.02  0.   ]
# irr_neg[0.004 0.008 0.01  0.002]
# first loop in j loop
# aucs0.79255856
# irr_pos[0.009 0.069 0.022 0.   ]
# irr_neg[0.009 0.011 0.012 0.   ]
# first loop in j loop
# aucs0.83593104
# irr_pos[0.01  0.083 0.019 0.   ]
# irr_neg[0.008 0.008 0.01  0.   ]
# first loop in j loop
# aucs0.94337872
# irr_pos[0.012 0.079 0.01  0.003]
# irr_neg[0.005 0.003 0.007 0.   ]
# first loop in j loop
# aucs0.9703248
# irr_pos[0.013 0.087 0.002 0.016]
# irr_neg[0.012 0.004 0.009 0.   ]
# first loop in j loop
# aucs0.9793004799999999
# irr_pos[0.013 0.08  0.001 0.025]
# irr_neg[0.013 0.008 0.017 0.001]
# first loop in j loop
# aucs0.99228304
# irr_pos[0.017 0.098 0.    0.017]
# irr_neg[0.005 0.009 0.006 0.   ]
# first loop in j loop
# aucs0.9981182399999999
# irr_pos[0.016 0.092 0.    0.017]
# irr_neg[0.007 0.005 0.009 0.053]
# first loop in j loop
# aucs0.9998232
# irr_pos[0.009 0.093 0.    0.027]
# irr_neg[0.012 0.007 0.005 0.109]
# first loop in j loop
# aucs0.99999152
# irr_pos[0.01  0.095 0.012 0.025]
# irr_neg[0.008 0.009 0.015 0.121]
# first loop in j loop
# aucs1.0
# irr_pos[0.011 0.081 0.025 0.02 ]
# irr_neg[0.01  0.009 0.011 0.117]
# first loop in j loop
# aucs1.0
# irr_pos[0.017 0.097 0.025 0.017]
# irr_neg[0.012 0.004 0.015 0.14 ]
# first loop in j loop
# aucs1.0
# irr_pos[0.017 0.097 0.021 0.024]
# irr_neg[0.012 0.008 0.012 0.117]
# first loop in j loop
# aucs1.0
# irr_pos[0.014 0.083 0.025 0.024]
# irr_neg[0.012 0.005 0.01  0.133]
# first loop in j loop
# aucs1.0
# irr_pos[0.006 0.095 0.023 0.024]
# irr_neg[0.009 0.011 0.015 0.138]
# first loop in j loop
# aucs1.0
# irr_pos[0.01  0.089 0.016 0.014]
# irr_neg[0.011 0.011 0.015 0.114]
# second loop in j loop
# aucs0.99855344
# irr_pos[0.012 0.099 0.    0.025]
# irr_neg[0.02  0.011 0.008 0.051]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.084 0.028 0.025]
# irr_neg[0.012 0.003 0.015 0.14 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.094 0.023 0.026]
# irr_neg[0.005 0.016 0.006 0.135]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.087 0.017 0.019]
# irr_neg[0.01  0.009 0.009 0.139]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.078 0.014 0.027]
# irr_neg[0.01  0.014 0.011 0.126]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.084 0.018 0.029]
# irr_neg[0.011 0.008 0.01  0.141]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.086 0.014 0.021]
# irr_neg[0.011 0.005 0.009 0.125]
# second loop in j loop
# aucs1.0
# irr_pos[0.016 0.065 0.017 0.027]
# irr_neg[0.018 0.012 0.013 0.126]
# second loop in j loop
# aucs1.0
# irr_pos[0.021 0.083 0.017 0.026]
# irr_neg[0.01  0.007 0.012 0.122]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.09  0.019 0.022]
# irr_neg[0.007 0.008 0.008 0.139]
# second loop in j loop
# aucs1.0
# irr_pos[0.015 0.106 0.024 0.015]
# irr_neg[0.011 0.007 0.011 0.133]
# second loop in j loop
# aucs1.0
# irr_pos[0.014 0.082 0.017 0.019]
# irr_neg[0.016 0.007 0.009 0.135]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.095 0.024 0.025]
# irr_neg[0.013 0.012 0.014 0.109]
# second loop in j loop
# aucs1.0
# irr_pos[0.022 0.09  0.023 0.027]
# irr_neg[0.006 0.01  0.017 0.127]
# second loop in j loop
# aucs1.0
# irr_pos[0.021 0.086 0.017 0.024]
# irr_neg[0.009 0.01  0.007 0.125]
# second loop in j loop
# aucs1.0
# irr_pos[0.017 0.069 0.017 0.023]
# irr_neg[0.007 0.013 0.015 0.143]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.103 0.022 0.02 ]
# irr_neg[0.009 0.012 0.006 0.133]
# after two j loops
# aucs1.0
# irr_pos[0.013 0.103 0.022 0.02 ]
# irr_neg[0.009 0.012 0.006 0.133]
# first loop in j loop
# aucs0.6721844799999999
# irr_pos[0.002 0.064 0.013 0.   ]
# irr_neg[0.    0.011 0.015 0.002]
# first loop in j loop
# aucs0.78782096
# irr_pos[0.01  0.063 0.021 0.   ]
# irr_neg[0.004 0.005 0.006 0.   ]
# first loop in j loop
# aucs0.7822947199999999
# irr_pos[0.01  0.069 0.016 0.   ]
# irr_neg[0.011 0.012 0.01  0.   ]
# first loop in j loop
# aucs0.8871099199999999
# irr_pos[0.016 0.077 0.012 0.01 ]
# irr_neg[0.006 0.004 0.013 0.   ]
# first loop in j loop
# aucs0.97652432
# irr_pos[0.011 0.078 0.006 0.017]
# irr_neg[0.011 0.    0.01  0.   ]
# first loop in j loop
# aucs0.9919132800000001
# irr_pos[0.01  0.102 0.008 0.02 ]
# irr_neg[0.014 0.002 0.014 0.   ]
# first loop in j loop
# aucs0.99555552
# irr_pos[0.014 0.079 0.002 0.021]
# irr_neg[0.017 0.005 0.008 0.   ]
# first loop in j loop
# aucs0.99952768
# irr_pos[0.016 0.077 0.001 0.018]
# irr_neg[0.011 0.006 0.019 0.09 ]
# first loop in j loop
# aucs0.99994576
# irr_pos[0.012 0.091 0.    0.024]
# irr_neg[0.013 0.005 0.012 0.127]
# first loop in j loop
# aucs0.99999936
# irr_pos[0.009 0.086 0.013 0.029]
# irr_neg[0.005 0.008 0.016 0.138]
# first loop in j loop
# aucs1.0
# irr_pos[0.016 0.102 0.02  0.019]
# irr_neg[0.013 0.008 0.014 0.123]
# first loop in j loop
# aucs1.0
# irr_pos[0.014 0.082 0.017 0.021]
# irr_neg[0.01  0.007 0.007 0.124]
# first loop in j loop
# aucs1.0
# irr_pos[0.012 0.092 0.02  0.023]
# irr_neg[0.01  0.011 0.011 0.131]
# second loop in j loop
# aucs0.99539936
# irr_pos[0.013 0.096 0.003 0.016]
# irr_neg[0.009 0.005 0.008 0.   ]
# second loop in j loop
# aucs0.99998528
# irr_pos[0.01  0.097 0.01  0.029]
# irr_neg[0.014 0.008 0.01  0.126]
# second loop in j loop
# aucs1.0
# irr_pos[0.01  0.083 0.018 0.024]
# irr_neg[0.014 0.006 0.007 0.132]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.099 0.022 0.02 ]
# irr_neg[0.016 0.012 0.013 0.142]
# second loop in j loop
# aucs1.0
# irr_pos[0.012 0.072 0.017 0.031]
# irr_neg[0.015 0.006 0.012 0.116]
# second loop in j loop
# aucs1.0
# irr_pos[0.009 0.105 0.019 0.015]
# irr_neg[0.015 0.008 0.006 0.14 ]
# second loop in j loop
# aucs1.0
# irr_pos[0.016 0.095 0.01  0.016]
# irr_neg[0.009 0.012 0.015 0.142]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.095 0.019 0.041]
# irr_neg[0.012 0.01  0.011 0.132]
# second loop in j loop
# aucs1.0
# irr_pos[0.007 0.09  0.022 0.033]
# irr_neg[0.014 0.012 0.008 0.154]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.094 0.027 0.017]
# irr_neg[0.009 0.013 0.017 0.122]
# second loop in j loop
# aucs1.0
# irr_pos[0.016 0.096 0.03  0.027]
# irr_neg[0.009 0.005 0.018 0.155]
# second loop in j loop
# aucs1.0
# irr_pos[0.017 0.09  0.016 0.026]
# irr_neg[0.013 0.003 0.015 0.129]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.083 0.022 0.022]
# irr_neg[0.01  0.005 0.013 0.145]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.079 0.022 0.018]
# irr_neg[0.01  0.006 0.011 0.104]
# second loop in j loop
# aucs1.0
# irr_pos[0.017 0.09  0.019 0.021]
# irr_neg[0.008 0.006 0.008 0.141]
# second loop in j loop
# aucs1.0
# irr_pos[0.011 0.101 0.018 0.017]
# irr_neg[0.009 0.009 0.012 0.118]
# second loop in j loop
# aucs1.0
# irr_pos[0.013 0.086 0.019 0.026]
# irr_neg[0.008 0.008 0.007 0.117]
# after two j loops
# aucs1.0
# irr_pos[0.013 0.086 0.019 0.026]
# irr_neg[0.008 0.008 0.007 0.117]
# after j loops
# aucs0.6603907200000001
# irr_pos[0.    0.09  0.014 0.   ]
# irr_neg[0.001 0.005 0.01  0.034]
# 0.7212876799999999

# %%
# 2D data visualization. The ellipses capture 95.45% of the data from the corresponding 
# distribution
import numpy as np
from itertools import combinations_with_replacement as comb
NMix.plotCIEllipse()
for (i,j) in comb(np.arange(n_comps),2):
    NMix.plotCIEllipse({'pos':[i],'neg':[j]})
    if i != j:
        NMix.plotCIEllipse({'pos':[i,j],'neg':[]})
        NMix.plotCIEllipse({'pos':[],'neg':[i,j]})

# %%
# You may change the mixing proportions within the + (or -) mixture or alpha as follows
p_pos = dirichlet(np.ones(n_comps)).rvs([])
p_neg = dirichlet(np.ones(n_comps)).rvs([])
dg.updateMixProps(alpha=0.3, p_pos = p_pos, p_neg = p_neg)
x, y = dg.pn_data(n)[0:2]
aucpn_final = AUCFromDistributions(dg.dist_p, dg.dist_n)
print(aucpn_final)
# Out:
# 0.687832

# %% [markdown]
# ### Approximating Irreducibility:
# We can quantify irreducibility as the probability mass of the region in the support of the positive density, where the negative density is $0$. This region can be defined in terms of the PN posterior as that region, where the PN posterior takes value of $1$. In theory, this is true irrespective of the value of the class prior. We relax the criteria of defining the region with a PN posterior of $1$ and instead define it with PN Posterior achieving value greater than $a$, for some value of $a$ close to 1.
# \begin{align*}
# I_a(f_1,f_0) &= \int \mathbf{I}[p(y=1|x)\geq a] f_1(x)dx\\
#  &= \mathbf{E}_{f_1}\big[\mathbf{I}[p(y=1|x)\geq a]\big]
# \end{align*}
# where $p(y=1|x)$ is the balalnced class posterior, i.e.,
# \begin{align*}
# p(y=1|x) &= \frac{0.5f_1(x)}{0.5f_1(x) + 0.5 f_0(x)} \\
# &= \frac{f_1(x)}{f_1(x) + f_0(x)}
# \end{align*}
# Notice that $I_1$ is the probability mass of the region in the support of positives, where the negatives have $0$ density. However, since Gaussian distribution is supported on the entire $R^d$ space, in theory $I_1$ is $0$. By choosing $a$ to be slightly below $1$ we relax the irreducibility criteria. For the data generation below, we used $a=0.95$
